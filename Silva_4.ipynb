# %% [markdown]
# # Chapter 4: The Seaborn essentials for data visualization

# %%
import pandas as pd

# %% [markdown]
# ## Get the data

# %%
mortality_data = pd.read_pickle('mortality_prepped.pkl')
mortality_data.head()
# Out:
#    Year     AgeGroup  DeathRate  MeanCentered
# 0  1900  01-04 Years     1983.8    1790.87584
# 1  1901  01-04 Years     1695.0    1502.07584
# 2  1902  01-04 Years     1655.7    1462.77584
# 3  1903  01-04 Years     1542.1    1349.17584
# 4  1904  01-04 Years     1591.5    1398.57584

# %% [markdown]
# ## The basic Seaborn parameters

# %%
import seaborn as sns

# %%
sns.relplot(data=mortality_data, kind='line',
            x='Year', y='DeathRate', hue='AgeGroup', aspect=2.4)

# %%
sns.lineplot(data=mortality_data, 
             x='Year', y='DeathRate', hue='AgeGroup')
# Out:
# <Axes: xlabel='Year', ylabel='DeathRate'>

# %%
sns.relplot(data=mortality_data, kind='line', 
            x='Year', y='DeathRate', hue='AgeGroup', palette='bright',
            height=4, aspect=1.5)

# %%
sns.relplot(data=mortality_data, 
            kind='line', x='Year', y='DeathRate', hue='AgeGroup', 
            height=4, aspect=1.25, 
            col='AgeGroup', col_wrap=2, legend=False)

# %% [markdown]
# ## Enhancing plots

# %%
ax = sns.lineplot(data=mortality_data, 
                  x='Year', y='DeathRate', hue='AgeGroup')
ax.set(title='Deaths by Age Group', ylabel='Deaths per 100,000', 
       xticks=[x for x in range(mortality_data['Year'].min(), mortality_data['Year'].max()+1, 5)])
# Out:
# [Text(0.5, 1.0, 'Deaths by Age Group'),
#  Text(0, 0.5, 'Deaths per 100,000'),
#  [<matplotlib.axis.XTick at 0x1f0c8d68c50>,
#   <matplotlib.axis.XTick at 0x1f0c8dbc2c0>,
#   <matplotlib.axis.XTick at 0x1f0c3e9c0e0>,
#   <matplotlib.axis.XTick at 0x1f0c95f8d40>,
#   <matplotlib.axis.XTick at 0x1f0c95f96a0>,
#   <matplotlib.axis.XTick at 0x1f0c95f9f10>,
#   <matplotlib.axis.XTick at 0x1f0c95fa840>,
#   <matplotlib.axis.XTick at 0x1f0c95fb0e0>,
#   <matplotlib.axis.XTick at 0x1f0c95fa120>,
#   <matplotlib.axis.XTick at 0x1f0c7cd1dc0>,
#   <matplotlib.axis.XTick at 0x1f0c8dd3a70>,
#   <matplotlib.axis.XTick at 0x1f0c96355b0>,
#   <matplotlib.axis.XTick at 0x1f0c9635bb0>,
#   <matplotlib.axis.XTick at 0x1f0c96368a0>,
#   <matplotlib.axis.XTick at 0x1f0c9637230>,
#   <matplotlib.axis.XTick at 0x1f0c9636e70>,
#   <matplotlib.axis.XTick at 0x1f0c9637a10>,
#   <matplotlib.axis.XTick at 0x1f0c9658350>,
#   <matplotlib.axis.XTick at 0x1f0c9658cb0>,
#   <matplotlib.axis.XTick at 0x1f0c9659580>,
#   <matplotlib.axis.XTick at 0x1f0c9659e50>,
#   <matplotlib.axis.XTick at 0x1f0c9659760>,
#   <matplotlib.axis.XTick at 0x1f0c965a390>,
#   <matplotlib.axis.XTick at 0x1f0c965acc0>]]

# %%
g = sns.relplot(data=mortality_data, kind='line',
    x='Year', y='DeathRate', hue='AgeGroup', aspect=1.5)
for ax in g.axes.flat:
    ax.set(title='Deaths by Age Group', ylabel='Deaths per 100,000')

# %%
g = sns.relplot(data=mortality_data, kind='line',
    x='Year', y='DeathRate', hue='AgeGroup', aspect=1.25)
for ax in g.axes.flat:
    ax.set(title='Deaths by Age Group (1910-1930)', ylabel='Deaths per 100,000', 
        xticks=[x for x in range(1910, 1931, 2)], 
        xlim=(1910,1930), ylim=(0,1750)),
    ax.tick_params('x', labelrotation=30)

# %%
ax = sns.lineplot(data=mortality_data,
     x='Year', y='DeathRate', hue='AgeGroup')
ax.set(title='Deaths by Age Group (1910-1930)', 
      ylabel='Deaths per 100,000', 
      xticks=[x for x in range(1910,1931,2)], 
      xlim=(1910,1930), ylim=(0,1750))
ax.tick_params('x', labelrotation=30)

# %%
sns.set_style('whitegrid')
sns.relplot(data=mortality_data.query('Year >= 1910 and Year <= 1930'),
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', aspect=1.25)

# %%
sns.set_style('darkgrid')
sns.relplot(data=mortality_data.query('Year >= 1910 and Year <= 1930'),
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', aspect=1.25, ci='sd')
# Out:
# C:\Users\sebas\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.set_style('ticks')

# %%
g = sns.relplot(data=mortality_data.query('Year >= 1910 and Year <= 1930'),
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', legend=False,
    col='AgeGroup', col_wrap=2, height=4)
g.fig.suptitle('Deaths by Age Group (1910-1930)', y=1.025)
g.set(ylabel='Deaths per 100,000', 
      xticks=[x for x in range(1910,1931,3)], 
      ylim=(0,1750))

# %% [markdown]
# ## Relational plots

# %%
sns.relplot(data=mortality_data, kind='line', x='Year', y='DeathRate', 
            hue='AgeGroup')

# %%
sns.relplot(data=mortality_data, kind='line', x='Year', y='DeathRate')

# %%
sns.regplot(data=mortality_data, x='Year', y='DeathRate', scatter=True)
# Out:
# <Axes: xlabel='Year', ylabel='DeathRate'>

# %%
g = sns.relplot(data=mortality_data.query('Year >= 1910 and Year <= 1930'), 
    kind='scatter', x='Year', y='DeathRate', hue='AgeGroup', 
    size='DeathRate', sizes=(10,100))
for ax in g.axes.flat:
    ax.set(xticks=[x for x in range(1910,1931,2)])

# %% [markdown]
# ## Categorical plots

# %%
sns.catplot(data=mortality_data.query('Year in (1950,2000)'), 
            kind='point', x='Year', y='DeathRate', ci=75)
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_19872\677087911.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 75)` for the same effect.
#
#   sns.catplot(data=mortality_data.query('Year in (1950,2000)'),

# %%
sns.catplot(data=mortality_data.query('Year in (1950,2000)'), 
            kind='bar', x='DeathRate', y='Year', hue='AgeGroup', orient='h')

# %%
sns.catplot(data=mortality_data.query('Year >= 1915 and Year <= 1920'), 
            kind='box', x='Year', y='DeathRate')

# %%
sns.catplot(data=mortality_data,
            kind='box', x='DeathRate', y='AgeGroup', orient='h')

# %% [markdown]
# ## Distribution plots

# %%
sns.displot(data=mortality_data, kind='hist', x='DeathRate', bins=32)

# %%
sns.displot(data=mortality_data, kind='hist', x='DeathRate', bins=8)

# %%
sns.displot(data=mortality_data, kind='kde', x='DeathRate')

# %%
sns.displot(data=mortality_data, kind='ecdf', x='DeathRate', hue='AgeGroup')

# %%
sns.displot(data=mortality_data, kind='hist', 
            x='DeathRate', kde=True, bins=8)

# %%
sns.displot(data=mortality_data, kind='kde', x='DeathRate', hue='AgeGroup', 
            fill=True, col='AgeGroup', col_wrap=2, height=3, legend=False)

# %% [markdown]
# ## Other techniques for enhancing a plot

# %%
g = sns.relplot(
    data=mortality_data, 
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', aspect=1.25)
for ax in g.axes.flat:
    ax.set_title('Deaths by Age Group (2000-2016)')
    ax.set_xlabel('')
    ax.set_xticks([x for x in range(2000,2017,2)])
    ax.set_xticklabels(['Year ' + str(x) for x in range(0,17,2)])
    ax.tick_params('x', labelrotation=30)
    ax.set_ylabel('Deaths per 100,000')
    ax.set_xlim(2000,2016)
    ax.set_ylim(0,80)

# %%
ax = sns.lineplot(data=mortality_data, 
                  x='Year', y='DeathRate', hue='AgeGroup')
ax.set_title('Deaths by Age Group')
ax.set_ylabel('Deaths per 100,000')
ax.annotate(text='Spanish Flu Pandemic', 
    xy=(1918, 1650), xytext=(1925, 1900), 
    arrowprops=dict(facecolor='red', width=3, headwidth=12, headlength=6))
# Out:
# Text(1925, 1900, 'Spanish Flu Pandemic')

# %%
colors = ['black','red','orange','blue']
sns.set_palette(sns.color_palette(colors))
sns.relplot(data=mortality_data, kind='line',
            x='Year', y='DeathRate', hue='AgeGroup')

# %%
sns.set_palette(sns.color_palette('tab10'))

# %%
g = sns.relplot(
    data=mortality_data.query('Year >= 1910 and Year <= 1930'),
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', legend=False,
    col='AgeGroup', col_wrap=2, height=3, aspect=1.2)
g.fig.suptitle('Deaths by Age Group (1910-1930)', y=1.025)
for ax in g.axes.flat:
    ax.set_ylabel('Deaths per 100,000')
    ax.set_xticks([x for x in range(1910, 1931, 2)])
    ax.tick_params('x', labelrotation=45)

# %%
g = sns.relplot(
    data=mortality_data.query('Year >= 1910 and Year <= 1930'), 
    kind='line', x='Year', y='DeathRate', hue='AgeGroup', legend=False, 
    col='AgeGroup', col_wrap=2, height=3, aspect=1.2)
g.fig.suptitle('Deaths by Age Group (1910-1930)', y=1.025)
ageGroups = mortality_data['AgeGroup'].drop_duplicates().tolist()
for index, ax in enumerate(g.axes.flat):
    ax.set_title(ageGroups[index])
    ax.set_ylabel('Deaths per 100,000')
    ax.set_xticks([x for x in range(1910, 1931, 2)])
    ax.tick_params('x', labelrotation=45)

# %%
# import a Matplotlib module and set the figure size
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,7.5)) 

# create the line plot
sns.lineplot(data=mortality_data, x='Year', y='DeathRate', hue='AgeGroup')

# use the ax and fig objects to enhance and save the plot
ax.set(title='Deaths by Age Group (1910-1930)', 
    ylabel='Deaths per 100,000', 
    xticks=[x for x in range(1910, 1931, 2)], 
    xlim=(1910,1930), ylim=(0,1750)),
ax.tick_params('x', labelrotation=45)

# %%
years = [1900, 1950, 2000]
filtered_data = mortality_data[mortality_data["Year"].isin(years)]

# %%
plt.figure(figsize=(9, 5))
sns.barplot(data=filtered_data, x="Year", y="DeathRate", hue="AgeGroup", ci=None)
plt.title("Average Death Rates for Selected Years")
plt.ylabel("Deaths per 100,000")
plt.show()
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_19872\1394484631.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=filtered_data, x="Year", y="DeathRate", hue="AgeGroup", ci=None)

# %%
g = sns.catplot(data=filtered_data, kind="bar", x="AgeGroup", y="DeathRate", col="Year",
                col_wrap=3, height=4, aspect=1.2, ci=None)
g.fig.suptitle("Death Rates by Age Group for Selected Years", y=1.05)
plt.show()
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_19872\329803121.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   g = sns.catplot(data=filtered_data, kind="bar", x="AgeGroup", y="DeathRate", col="Year",

# %%
age_15_19 = mortality_data[mortality_data["AgeGroup"] == "15-19"]
plt.figure(figsize=(8, 5))
sns.lineplot(data=age_15_19, x="Year", y="DeathRate")
plt.title("Death Rates for 15-19 Age Group Over Time")
plt.ylabel("Deaths per 100,000")
plt.show()

# %%
filtered_range = mortality_data[(mortality_data["Year"] >= 1950) & (mortality_data["Year"] <= 2000)]
plt.figure(figsize=(10, 5))
sns.lineplot(data=filtered_range, x="Year", y="DeathRate", hue="AgeGroup")
plt.title("Death Rates by Age Group (1950-2000)")
plt.ylabel("Deaths per 100,000")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(data=filtered_range, x="Year", y="DeathRate", hue="AgeGroup", size="DeathRate", sizes=(10, 100))
plt.title("Death Rates by Age Group (1950-2000) - Scatter Plot")
plt.ylabel("Deaths per 100,000")
plt.show()

# %%
selected_years = [1900, 1925, 1950, 1975, 2000]
subset_data = mortality_data[mortality_data["Year"].isin(selected_years)]

fig, axes = plt.subplots(2, 2, figsize=(12, 8))  # Two rows, two columns
fig.suptitle("Death Rates by Age Group for Selected Years", fontsize=14, y=1.02)

for ax, year in zip(axes.flat, selected_years):
    sns.barplot(data=subset_data[subset_data["Year"] == year], x="AgeGroup", y="DeathRate", ax=ax, ci=None)
    ax.set_title(f"Year {year}")
    ax.set_ylabel("Deaths per 100,000")

plt.tight_layout()
plt.savefig("barCharts.png")
plt.show()
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_19872\3480634760.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=subset_data[subset_data["Year"] == year], x="AgeGroup", y="DeathRate", ax=ax, ci=None)
# C:\Users\sebas\AppData\Local\Temp\ipykernel_19872\3480634760.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=subset_data[subset_data["Year"] == year], x="AgeGroup", y="DeathRate", ax=ax, ci=None)
# C:\Users\sebas\AppData\Local\Temp\ipykernel_19872\3480634760.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=subset_data[subset_data["Year"] == year], x="AgeGroup", y="DeathRate", ax=ax, ci=None)
# C:\Users\sebas\AppData\Local\Temp\ipykernel_19872\3480634760.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=subset_data[subset_data["Year"] == year], x="AgeGroup", y="DeathRate", ax=ax, ci=None)
